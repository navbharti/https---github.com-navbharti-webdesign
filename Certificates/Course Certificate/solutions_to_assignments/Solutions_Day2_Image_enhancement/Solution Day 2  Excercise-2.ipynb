# %% [markdown]
# ### Excercise 2
# Read the image lc_lena.png inside Day2 folder. Enhance the quality of image by applying relevant image enhancement operations.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lena=plt.imread('lc_lena.png')
plt.imshow(lena)

# %%
from scipy import ndimage
lena = ndimage.rotate(lena, 90, reshape=False)
plt.imshow(lena)

# %%
from skimage import exposure  # to call histogram equalization function
lena= exposure.equalize_hist(lena)
plt.imshow(img_eq,cmap='gray')

# %% [markdown]
# 2. Remove noise from image using
#
# Apply wiener filter

# %%
from skimage.restoration import wiener
import numpy as np
from skimage.color import rgb2gray
lena=rgb2gray(lena)
psf = np.ones((3, 3))/9       #Point Spread Function
d_lena=wiener(lena,psf, 2)
plt.imshow(d_lena,cmap='gray')

# %% [markdown]
# Sharpen the image

# %%
from skimage import color, data, restoration
psf = np.ones((3, 3)) / 9
rl_lena = restoration.richardson_lucy(d_lena, psf, iterations=30)  # recovering an underlying image that has been blurred
plt.imshow(rl_lena,cmap='gray')
